# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../data/final_df.csv')

# %%
df = df[df['longitude'] < -20]

# %%
fig, ax = plt.subplots()
ax.scatter(df['longitude'],df['latitude'],alpha=.1)
ax.set_title('Geographic distribution of restaurants')
ax.set_xlabel('Latitude')
ax.set_ylabel('Longitude')
# Out:
# Text(0,0.5,'Longitude')

# %%
df['closed_on_google'].value_counts().plot(kind='bar',title="Count of restaurants closed/opened")

# %%
df['']
